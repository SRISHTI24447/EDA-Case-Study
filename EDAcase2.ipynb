# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
#Importing libraries for Analysis

# %%
df=pd.read_csv(r"C:\Users\SRISHTI\Downloads\Bank+Dataset (1)\Bank Dataset\bank_marketing_updated_v1.csv")
df
# Out:
#           banking marketing Unnamed: 1                    Unnamed: 2  \
# 0      customer id and age.        NaN  Customer salary and balance.
# 1                customerid        age                        salary
# 2                         1         58                        100000
# 3                         2         44                         60000
# 4                         3         33                        120000
# ...                     ...        ...                           ...
# 45208                 45207       51.0                         60000
# 45209                 45208       71.0                         55000
# 45210                 45209       72.0                         55000
# 45211                 45210       57.0                         20000
# 45212                 45211       37.0                        120000
#
#       Unnamed: 3                                         Unnamed: 4  \
# 0            NaN  Customer marital status and job with education...
# ...

# %%
df.shape
# Out:
# (45213, 19)

# %%
df.head
# Out:
# <bound method NDFrame.head of           banking marketing Unnamed: 1                    Unnamed: 2  \
# 0      customer id and age.        NaN  Customer salary and balance.
# 1                customerid        age                        salary
# 2                         1         58                        100000
# 3                         2         44                         60000
# 4                         3         33                        120000
# ...                     ...        ...                           ...
# 45208                 45207       51.0                         60000
# 45209                 45208       71.0                         55000
# 45210                 45209       72.0                         55000
# 45211                 45210       57.0                         20000
# 45212                 45211       37.0                        120000
#
#       Unnamed: 3                                         Unnamed: 4  \
# ...

# %%
#Read in the dataset

# %%
#data cleaning

# %%
df=pd.read_csv(r"C:\Users\SRISHTI\Downloads\Bank+Dataset (1)\Bank Dataset\bank_marketing_updated_v1.csv",skiprows=2)
df
# Out:
#        customerid   age  salary  balance   marital                  jobedu  \
# 0               1  58.0  100000     2143   married     management,tertiary
# 1               2  44.0   60000       29    single    technician,secondary
# 2               3  33.0  120000        2   married  entrepreneur,secondary
# 3               4  47.0   20000     1506   married     blue-collar,unknown
# 4               5  33.0       0        1    single         unknown,unknown
# ...           ...   ...     ...      ...       ...                     ...
# 45206       45207  51.0   60000      825   married     technician,tertiary
# 45207       45208  71.0   55000     1729  divorced         retired,primary
# 45208       45209  72.0   55000     5715   married       retired,secondary
# 45209       45210  57.0   20000      668   married   blue-collar,secondary
# 45210       45211  37.0  120000     2971   married  entrepreneur,secondary
#
#       targeted default housing loan    contact  day      month  \
# ...

# %%
###Dropping customer id column

# %%
df.drop("customerid",axis=1,inplace=True)
df
# Out:
#         age  salary  balance   marital                  jobedu targeted  \
# 0      58.0  100000     2143   married     management,tertiary      yes
# 1      44.0   60000       29    single    technician,secondary      yes
# 2      33.0  120000        2   married  entrepreneur,secondary      yes
# 3      47.0   20000     1506   married     blue-collar,unknown       no
# 4      33.0       0        1    single         unknown,unknown       no
# ...     ...     ...      ...       ...                     ...      ...
# 45206  51.0   60000      825   married     technician,tertiary      yes
# 45207  71.0   55000     1729  divorced         retired,primary      yes
# 45208  72.0   55000     5715   married       retired,secondary      yes
# 45209  57.0   20000      668   married   blue-collar,secondary      yes
# 45210  37.0  120000     2971   married  entrepreneur,secondary      yes
#
#       default housing loan    contact  day      month              duration  \
# ...

# %%
#Diving jobdu into job education

# %%
df['job']=df.jobedu.apply(lambda x:x.split(",")[0])
df
# Out:
#         age  salary  balance   marital                  jobedu targeted  \
# 0      58.0  100000     2143   married     management,tertiary      yes
# 1      44.0   60000       29    single    technician,secondary      yes
# 2      33.0  120000        2   married  entrepreneur,secondary      yes
# 3      47.0   20000     1506   married     blue-collar,unknown       no
# 4      33.0       0        1    single         unknown,unknown       no
# ...     ...     ...      ...       ...                     ...      ...
# 45206  51.0   60000      825   married     technician,tertiary      yes
# 45207  71.0   55000     1729  divorced         retired,primary      yes
# 45208  72.0   55000     5715   married       retired,secondary      yes
# 45209  57.0   20000      668   married   blue-collar,secondary      yes
# 45210  37.0  120000     2971   married  entrepreneur,secondary      yes
#
#       default housing loan    contact  day      month              duration  \
# ...

# %%
df['education']=df.jobedu.apply(lambda x: x.split(",")[1])
df
# Out:
#         age  salary  balance   marital                  jobedu targeted  \
# 0      58.0  100000     2143   married     management,tertiary      yes
# 1      44.0   60000       29    single    technician,secondary      yes
# 2      33.0  120000        2   married  entrepreneur,secondary      yes
# 3      47.0   20000     1506   married     blue-collar,unknown       no
# 4      33.0       0        1    single         unknown,unknown       no
# ...     ...     ...      ...       ...                     ...      ...
# 45206  51.0   60000      825   married     technician,tertiary      yes
# 45207  71.0   55000     1729  divorced         retired,primary      yes
# 45208  72.0   55000     5715   married       retired,secondary      yes
# 45209  57.0   20000      668   married   blue-collar,secondary      yes
# 45210  37.0  120000     2971   married  entrepreneur,secondary      yes
#
#       default housing loan    contact  day      month              duration  \
# ...

# %%
df.drop("jobedu",axis=1,inplace=True)
df
# Out:
#         age  salary  balance   marital targeted default housing loan  \
# 0      58.0  100000     2143   married      yes      no     yes   no
# 1      44.0   60000       29    single      yes      no     yes   no
# 2      33.0  120000        2   married      yes      no     yes  yes
# 3      47.0   20000     1506   married       no      no     yes   no
# 4      33.0       0        1    single       no      no      no   no
# ...     ...     ...      ...       ...      ...     ...     ...  ...
# 45206  51.0   60000      825   married      yes      no      no   no
# 45207  71.0   55000     1729  divorced      yes      no      no   no
# 45208  72.0   55000     5715   married      yes      no      no   no
# 45209  57.0   20000      668   married      yes      no      no   no
# 45210  37.0  120000     2971   married      yes      no      no   no
#
#          contact  day      month              duration  campaign  pdays  \
# ...

# %%
#Extract the value of month drom the colum month

# %%
df.month = df.month.apply(lambda x: x.split(",")[0])
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df.month = df.month.apply(lambda x: x.split(",")[0])
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# ...

# %%
df[df.month.apply(lambda x: isinstance(x,float))==True]
# Out:
#         age  salary  balance   marital targeted default housing loan  \
# 189    31.0  100000        0    single       no      no     yes   no
# 769    39.0   20000      245   married      yes      no     yes   no
# 860    33.0   55000      165   married      yes      no      no   no
# 1267   36.0   50000      114   married      yes      no     yes  yes
# 1685   34.0   20000      457   married      yes      no     yes   no
# 1899   49.0   16000      164  divorced      yes      no     yes   no
# 2433   26.0   60000     3825   married      yes      no     yes   no
# 2612   38.0   50000      446    single       no      no     yes   no
# 2747   48.0  120000     2550   married       no      no     yes   no
# 3556   41.0   20000       59   married      yes      no     yes   no
# 3890   56.0   55000     4391   married       no      no     yes   no
# 5311   22.0   20000        0    single      yes      no     yes   no
# 6265   32.0   50000       13    single      yes      no     yes   no
# ...

# %%
chaecking the missing values
# Out:
#   Cell In[58], line 1
#     chaecking the missing values
#               ^
# SyntaxError: invalid syntax

# %%
df.isnull().sum()
# Out:
# age          20
# salary        0
# balance       0
# marital       0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month        50
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response     30
# job           0
# education     0
# dtype: int64

# %%
#handling missing values

# %%
df.age.isnull().sum()
# Out:
# 20

# %%
df.shape
# Out:
# (45211, 19)

# %%
float(100.0*20/45211)
# Out:
# 0.04423702196368141

# %%
#DRop records with age missing

# %%
df=df[~df.age.isnull()].copy()
df.shape
# Out:
# (45191, 19)

# %%
#Handling missing vallues in month

# %%
df.month.isnull().sum()
# Out:
# 50

# %%
df.month.value_counts(normalize=True)
# Out:
# month
# may, 2017    0.304380
# jul, 2017    0.152522
# aug, 2017    0.138123
# jun, 2017    0.118141
# nov, 2017    0.087880
# apr, 2017    0.064908
# feb, 2017    0.058616
# jan, 2017    0.031058
# oct, 2017    0.016327
# sep, 2017    0.012760
# mar, 2017    0.010545
# dec, 2017    0.004741
# Name: proportion, dtype: float64

# %%
df.month.mode()
# Out:
# 0    may, 2017
# Name: month, dtype: object

# %%
month_mode=df.month.mode()[0]
month_mode
# Out:
# 'may, 2017'

# %%
df.month.fillna(month_mode,inplace=True)
df.month.value_counts(normalize=True)
# Out:
# month
# may, 2017    0.305149
# jul, 2017    0.152353
# aug, 2017    0.137970
# jun, 2017    0.118010
# nov, 2017    0.087783
# apr, 2017    0.064836
# feb, 2017    0.058551
# jan, 2017    0.031024
# oct, 2017    0.016309
# sep, 2017    0.012746
# mar, 2017    0.010533
# dec, 2017    0.004735
# Name: proportion, dtype: float64

# %%
df.month.isnull().sum()
# Out:
# 0

# %%
df.pdays.describe()
# Out:
# count    45191.000000
# mean        40.181253
# std        100.074099
# min         -1.000000
# 25%         -1.000000
# 50%         -1.000000
# 75%         -1.000000
# max        871.000000
# Name: pdays, dtype: float64

# %%
-1 indicates missing values
# Out:
#   Cell In[90], line 1
#     -1 indicates missing values
#        ^
# SyntaxError: invalid syntax

# %%
###how do we handle this
##rember our objective?/
#-ve want the missing values to be ignored on the calcluations
#-simply make it missing-replace-1 with NaN
#-all summary statistic-mean,modian etc will ignore the missing values.

# %%
df.loc[df.pdays<0,"pdays"]=np.NaN
df.pdays.describe()
# Out:
# count    8252.000000
# mean      224.523752
# std       115.202715
# min         1.000000
# 25%       133.000000
# 50%       194.500000
# 75%       327.000000
# max       871.000000
# Name: pdays, dtype: float64

# %%
df.response.isnull().sum()
# Out:
# 30

# %%
values=df['response'].isnull().mean() * 100
df
# Out:
#         age  salary  balance   marital targeted default housing loan  \
# 0      58.0  100000     2143   married      yes      no     yes   no
# 1      44.0   60000       29    single      yes      no     yes   no
# 2      33.0  120000        2   married      yes      no     yes  yes
# 3      47.0   20000     1506   married       no      no     yes   no
# 4      33.0       0        1    single       no      no      no   no
# ...     ...     ...      ...       ...      ...     ...     ...  ...
# 45206  51.0   60000      825   married      yes      no      no   no
# 45207  71.0   55000     1729  divorced      yes      no      no   no
# 45208  72.0   55000     5715   married      yes      no      no   no
# 45209  57.0   20000      668   married      yes      no      no   no
# 45210  37.0  120000     2971   married      yes      no      no   no
#
#          contact  day      month              duration  campaign  pdays  \
# ...

# %%
missing_percentage = df['response'].isnull().mean() * 100
print(f"Percentage of missing values in 'response' column: {missing_percentage}%")
# Out:
# Percentage of missing values in 'response' column: 0.06638489964816004%

# %%
#Missing value doen't always have to be present as  null

# %%
#Outliers handling

# %%
#Age variable

# %%
df.age.describe()
# Out:
# count    45191.000000
# mean        40.935651
# std         10.619198
# min         18.000000
# 25%         33.000000
# 50%         39.000000
# 75%         48.000000
# max         95.000000
# Name: age, dtype: float64

# %%
df.age.plot.hist()
plt.show()

# %%
sns.boxplot(df.age)
plt.show()

# %%
###Balance variable

# %%
df.balance.describe()
# Out:
# count     45191.000000
# mean       1362.432520
# std        3045.120417
# min       -8019.000000
# 25%          72.000000
# 50%         448.000000
# 75%        1428.000000
# max      102127.000000
# Name: balance, dtype: float64

# %%
plt.figure(figsize=[8,2])
sns.boxplot(x=df.balance)
plt.show()

# %%
df.balance.quantile([0.5,0.7,0.9,0.95,0.99])
# Out:
# 0.50      448.0
# 0.70     1126.0
# 0.90     3575.0
# 0.95     5768.0
# 0.99    13167.1
# Name: balance, dtype: float64

# %%
df[df.balance>15000].describe()
# Out:
#               age         salary        balance         day    campaign  \
# count  351.000000     351.000000     351.000000  351.000000  351.000000
# mean    45.341880   70008.547009   24295.780627   16.022792    2.749288
# std     12.114333   34378.272805   12128.560693    8.101819    3.036886
# min     23.000000       0.000000   15030.000000    1.000000    1.000000
# 25%     35.000000   50000.000000   17074.000000    9.000000    1.000000
# 50%     44.000000   60000.000000   20723.000000   18.000000    2.000000
# 75%     55.000000  100000.000000   26254.000000   21.000000    3.000000
# max     84.000000  120000.000000  102127.000000   31.000000   31.000000
#
#             pdays    previous
# count   62.000000  351.000000
# mean   188.516129    0.555556
# std    118.796388    1.784590
# min     31.000000    0.000000
# 25%     96.250000    0.000000
# 50%    167.500000    0.000000
# 75%    246.500000    0.000000
# max    589.000000   23.000000

# %%
Instead of looking at mean, we could look at quantile/medians/percentiles instead
# Out:
#   Cell In[121], line 1
#     Instead of looking at mean, we could look at quantile/medians/percentiles instead
#             ^
# SyntaxError: invalid syntax

# %%
df.salary.describe()

# %%
df.duration.describe()

# %%
plt.figure(figsize=[8,2])
sns.boxplot(x=df.duration)
plt.show()

# %%
Standardize variable
# Out:
#   Cell In[129], line 1
#     Standardize variable
#                 ^
# SyntaxError: invalid syntax

# %%
df.duration.head(10)

# %%
df.duration.describe()# we are converting timing min to sec it should be one

# %%
df.duration=df.duration.apply(lambda x:float( x.split()[0]/60)if x.find("sec")>0 else float(x.split()[0]))

# %%
df.duration.describe()

# %%
df.dtypes

# %%
Univariate analysis

# %%
df.marital.value_counts()

# %%
df.marital.value_counts(normalize=True)

# %%
df.dtypes

# %%
#Univariate analysis- categorical featrure

# %%
df.marital.value_counts()

# %%
df.marital.value_counts(normalize=True)
# Out:
# marital
# married     0.601978
# single      0.282932
# divorced    0.115089
# Name: proportion, dtype: float64

# %%
df.marital.value_counts(normalize=True).plot.barh()
plt.show()

# %%
df.job.value_counts(normalize=True).plot.barh()
plt.show()

# %%
#Education Variable

# %%
df.education.value_counts(normalize=True)
# Out:
# education
# secondary    0.513222
# tertiary     0.294196
# primary      0.151490
# unknown      0.041092
# Name: proportion, dtype: float64

# %%
df.education.value_counts(normalize=True).plot.pie()
plt.show()

# %%
##outcome variable

# %%
df.poutcome.value_counts(normalize=True).plot.bar()
plt.show()

# %%
df[~(df.poutcome=="unknown")].poutcome.value_counts(normalize=True).plot.bar()
plt.show()

# %%
response-the target variable

# %%
df.response.value_counts(normalize=True)

# %%
df.response.value_counts(normalize=True).plot.pie()
plt.show()

# %%
#Bi-variate analyse

# %%
Numercial-numercial

# %%
plt.scatter(df.salary,df.balance)
plt.show()

# %%
df.plot.scatter(x="age",y="balance")
plt.show()

# %%
sns.pairplot(data=df,vars=["salary","balance","age"])
plt.show()

# %%
#Quantify using correlation method
# Out:
#   Cell In[164], line 1
#     Quantify using correlation method
#              ^
# SyntaxError: invalid syntax

# %%
df[["age","salary","balance"]].corr()
# Out:
#               age    salary   balance
# age      1.000000  0.024374  0.097755
# salary   0.024374  1.000000  0.055505
# balance  0.097755  0.055505  1.000000

# %%
coorelation heat map

# %%
sns.heatmap(df[["age","salary","balance"]].corr(),annot=True,cmap="Reds")
plt.show()

# %%
#Categorical numercial

# %%
df.groupby("response")["salary"].mean()
# Out:
# response
# no     56769.510482
# yes    58780.510880
# Name: salary, dtype: float64

# %%
df.groupby("response")["salary"].median()
# Out:
# response
# no     60000.0
# yes    60000.0
# Name: salary, dtype: float64

# %%
sns.boxplot(data=df,x="response",y="salary")
plt.show()

# %%
#response vs.balance
#we know that balance is hightly skewd-has very hight valus

# %%
sns.boxplot(data=df,x="response",y="balance")
plt.show()

# %%
df.groupby('response')["balance"].mean()
# Out:
# response
# no     1304.292281
# yes    1804.681362
# Name: balance, dtype: float64

# %%
df.groupby('response')["balance"].median()
# Out:
# response
# no     417.0
# yes    733.0
# Name: balance, dtype: float64

# %%
#75th pecentile

# %%
def p75(x):
    return np.quantile(x,0.75)

# %%
df.groupby('response')['balance'].aggregate(["mean","median",p75])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[192], line 1
# ----> 1 df.groupby('response')['balance'].aggregate(["mean","median",p75])
#
# NameError: name 'p75' is not defined

# %%
df.groupby('response')['balance'].aggregate(["mean","median",]).plot.bar()
plt.show()

# %%
Categorical-categorial

# %%
df['response_flag']=np.where(df.response=="yes",1,0)

# %%
df.response_flag.value_counts()
# Out:
# response_flag
# 0    39906
# 1     5285
# Name: count, dtype: int64

# %%
df.response.value_counts()
# Out:
# response
# no     39876
# yes     5285
# Name: count, dtype: int64

# %%
df.response.value_counts(normalize=True)
# Out:
# response
# no     0.882974
# yes    0.117026
# Name: proportion, dtype: float64

# %%
df.response_flag.mean()
# Out:
# 0.11694806488017526

# %%
#education vs response rate

# %%
df.groupby(['education'])['response_flag'].mean()
# Out:
# education
# primary      0.086328
# secondary    0.105549
# tertiary     0.149981
# unknown      0.135703
# Name: response_flag, dtype: float64

# %%
Martial vs response rate

# %%
df.groupby(["marital"])['response'].mean().plot.barh()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# ...

# %%
df.groupby(["loan"])['response'].mean().plot.barh()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# ...

# %%
sns.boxplot(data=df,x="response",y="age")#age vs response
plt.show()

# %%
#Making bukets from the age columns

# %%
pd.cut?
# Out:
# Signature:
# pd.cut(
#     x,
#     bins,
#     right: 'bool' = True,
#     labels=None,
#     retbins: 'bool' = False,
#     precision: 'int' = 3,
#     include_lowest: 'bool' = False,
#     duplicates: 'str' = 'raise',
#     ordered: 'bool' = True,
# )
# Docstring:
# Bin values into discrete intervals.
#
# Use `cut` when you need to segment and sort data values into bins. This
# function is also useful for going from a continuous variable to a
# categorical variable. For example, `cut` could convert ages to groups of
# age ranges. Supports binning into an equal number of bins, or a
# pre-specified array of bins.
#
# Parameters
# ----------
# x : array-like
#     The input array to be binned. Must be 1-dimensional.
# bins : int, sequence of scalars, or IntervalIndex
#     The criteria to bin by.
#
#     * int : Defines the number of equal-width bins in the range of `x`. The
#       range of `x` is extended by .1% on each side to include the minimum
# ...

# %%
pd.cut(df.age,[0,30,40,50,60,9999],labels=["<30","30-40","40-50","50-60","60+"])
# Out:
# 0        50-60
# 1        40-50
# 2        30-40
# 3        40-50
# 4        30-40
#          ...
# 45206    50-60
# 45207      60+
# 45208      60+
# 45209    50-60
# 45210    30-40
# Name: age, Length: 45191, dtype: category
# Categories (5, object): ['<30' < '30-40' < '40-50' < '50-60' < '60+']

# %%
df.age.head()
# Out:
# 0    58.0
# 1    44.0
# 2    33.0
# 3    47.0
# 4    33.0
# Name: age, dtype: float64

# %%
df['age_group']=pd.cut(df.age,[0,30,40,50,60,9999],labels=["<30","30-40","40-50","50-60","60+"])

# %%
df.age_group.value_counts(normalize=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15152\2663413780.py in ?()
# ----> 1 df.age_group.value_counts(normalize=True)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'age_group'

# %%
df.age_group.value_counts(normalize=True0.plot()
